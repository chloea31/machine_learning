# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex4 import *

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

spotify = pd.read_csv('../data/raw/deep_neural_networks/spotify.csv')

X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

# We'll do a "grouped" split to keep all of an artist's songs in one
# split or the other. This is to help prevent signal leakage.
def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100 # popularity is on a scale 0-100, so this rescales to 0-1.
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# 2025-05-18 21:14:56.416452: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747595696.449106     879 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747595696.461578     879 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 21:14:56.590092: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Input shape: [18]

# %%
model = keras.Sequential([
    layers.Dense(1, input_shape=input_shape),
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    verbose=0, # suppress output since we'll plot the curves
)
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# /home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1747595861.185309     879 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# W0000 00:00:1747595861.832407   27171 gpu_backend_lib.cc:579] Can't find libdevice directory ${CUDA_DIR}/nvvm/libdevice. This may result in compilation or runtime failures, if the program we try to run uses routines from libdevice.
# Searched for CUDA in the following directories:
#   ./cuda_sdk_lib
#   ipykernel_launcher.runfiles/cuda_nvcc
#   ipykern/cuda_nvcc
#
#   /usr/local/cuda
#   /home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc
#   /home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc
#   /home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/tensorflow/python/platform/../../cuda
#   .
# You can choose the search directory by setting xla_gpu_cuda_data_dir in HloModule's DebugOptions.  For most apps, setting the environment variable XLA_FLAGS=--xla_gpu_cuda_data_dir=/path/to/cuda will work.
# I0000 00:00:1747595863.604253   27163 service.cc:148] XLA service 0x7f67a80065f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747595863.604311   27163 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-05-18 21:17:43.666331: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747595863.780638   27163 cuda_dnn.cc:529] Loaded cuDNN version 90800
# W0000 00:00:1747595863.976195   27163 gpu_backend_lib.cc:617] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2025-05-18 21:17:43.979354: W tensorflow/core/framework/op_kernel.cc:1841] OP_REQUIRES failed at xla_ops.cc:577 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2025-05-18 21:17:43.979496: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INTERNAL: libdevice not found at ./libdevice.10.bc
# 	 [[{{node StatefulPartitionedCall}}]]
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[3], line 8
#       1 model = keras.Sequential([
#       2     layers.Dense(1, input_shape=input_shape),
#       3 ])
#       4 model.compile(
#       5     optimizer='adam',
#       6     loss='mae',
#       7 )
# ----> 8 history = model.fit(
#       9     X_train, y_train,
#      10     validation_data=(X_valid, y_valid),
#      11     batch_size=512,
#      12     epochs=50,
#      13     verbose=0, # suppress output since we'll plot the curves
#      14 )
#      15 history_df = pd.DataFrame(history.history)
#      16 history_df.loc[0:, ['loss', 'val_loss']].plot()
#
# File ~/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniforge3/envs/EnvDL/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/asyncio/events.py", line 88, in _run
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3098, in run_cell
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3153, in _run_cell
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3365, in run_cell_async
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3610, in run_ast_nodes
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3670, in run_code
#
#   File "/tmp/ipykernel_879/1440710233.py", line 8, in <module>
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 371, in fit
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 219, in function
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 132, in multi_step_on_iterator
#
# libdevice not found at ./libdevice.10.bc
# 	 [[{{node StatefulPartitionedCall}}]] [Op:__inference_multi_step_on_iterator_606]

# %%
# Start the plot at epoch 10
history_df.loc[10:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Start the plot at epoch 10
# ----> 2 history_df.loc[10:, ['loss', 'val_loss']].plot()
#       3 print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
#
# NameError: name 'history_df' is not defined

# %% [markdown]
# ## 1) Evaluate baseline

# %%
# View the solution (Run this cell to receive credit!)
q_1.check()
# Out:
# Correct:
#
# The gap between these curves is quite small and the validation loss never increases, so it's more likely that the network is underfitting than overfitting. It would be worth experimenting with more capacity to see if that's the case.

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# /home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# E0000 00:00:1747597371.533574   27163 buffer_comparator.cc:157] Difference at 16: 0, expected 264.876
# E0000 00:00:1747597371.533714   27163 buffer_comparator.cc:157] Difference at 17: 0, expected 253.655
# E0000 00:00:1747597371.533725   27163 buffer_comparator.cc:157] Difference at 18: 0, expected 244.343
# E0000 00:00:1747597371.533730   27163 buffer_comparator.cc:157] Difference at 19: 0, expected 250.485
# E0000 00:00:1747597371.533733   27163 buffer_comparator.cc:157] Difference at 20: 0, expected 246.392
# E0000 00:00:1747597371.533737   27163 buffer_comparator.cc:157] Difference at 21: 0, expected 249.136
# E0000 00:00:1747597371.533740   27163 buffer_comparator.cc:157] Difference at 22: 0, expected 256.307
# E0000 00:00:1747597371.533744   27163 buffer_comparator.cc:157] Difference at 23: 0, expected 246.965
# E0000 00:00:1747597371.533747   27163 buffer_comparator.cc:157] Difference at 24: 0, expected 256.769
# E0000 00:00:1747597371.533750   27163 buffer_comparator.cc:157] Difference at 25: 0, expected 251.869
# 2025-05-18 21:42:51.533763: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.538314   27163 buffer_comparator.cc:157] Difference at 16: 0, expected 264.876
# E0000 00:00:1747597371.538374   27163 buffer_comparator.cc:157] Difference at 17: 0, expected 253.655
# E0000 00:00:1747597371.538384   27163 buffer_comparator.cc:157] Difference at 18: 0, expected 244.343
# E0000 00:00:1747597371.538388   27163 buffer_comparator.cc:157] Difference at 19: 0, expected 250.485
# E0000 00:00:1747597371.538391   27163 buffer_comparator.cc:157] Difference at 20: 0, expected 246.392
# E0000 00:00:1747597371.538395   27163 buffer_comparator.cc:157] Difference at 21: 0, expected 249.136
# E0000 00:00:1747597371.538398   27163 buffer_comparator.cc:157] Difference at 22: 0, expected 256.307
# E0000 00:00:1747597371.538402   27163 buffer_comparator.cc:157] Difference at 23: 0, expected 246.965
# E0000 00:00:1747597371.538405   27163 buffer_comparator.cc:157] Difference at 24: 0, expected 256.769
# E0000 00:00:1747597371.538409   27163 buffer_comparator.cc:157] Difference at 25: 0, expected 251.869
# 2025-05-18 21:42:51.538419: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.542602   27163 buffer_comparator.cc:157] Difference at 16: 0, expected 264.876
# E0000 00:00:1747597371.542658   27163 buffer_comparator.cc:157] Difference at 17: 0, expected 253.655
# E0000 00:00:1747597371.542668   27163 buffer_comparator.cc:157] Difference at 18: 0, expected 244.343
# E0000 00:00:1747597371.542672   27163 buffer_comparator.cc:157] Difference at 19: 0, expected 250.485
# E0000 00:00:1747597371.542676   27163 buffer_comparator.cc:157] Difference at 20: 0, expected 246.392
# E0000 00:00:1747597371.542680   27163 buffer_comparator.cc:157] Difference at 21: 0, expected 249.136
# E0000 00:00:1747597371.542683   27163 buffer_comparator.cc:157] Difference at 22: 0, expected 256.307
# E0000 00:00:1747597371.542686   27163 buffer_comparator.cc:157] Difference at 23: 0, expected 246.965
# E0000 00:00:1747597371.542690   27163 buffer_comparator.cc:157] Difference at 24: 0, expected 256.769
# E0000 00:00:1747597371.542693   27163 buffer_comparator.cc:157] Difference at 25: 0, expected 251.869
# 2025-05-18 21:42:51.542701: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.548232   27163 buffer_comparator.cc:157] Difference at 1: 290.553, expected 256.133
# E0000 00:00:1747597371.548324   27163 buffer_comparator.cc:157] Difference at 2: 296.042, expected 258.13
# E0000 00:00:1747597371.548339   27163 buffer_comparator.cc:157] Difference at 3: 298.279, expected 259.283
# E0000 00:00:1747597371.549780   27163 buffer_comparator.cc:157] Difference at 6: 304.153, expected 262.422
# E0000 00:00:1747597371.549846   27163 buffer_comparator.cc:157] Difference at 12: 293.764, expected 256.602
# E0000 00:00:1747597371.549856   27163 buffer_comparator.cc:157] Difference at 16: 312.238, expected 264.876
# E0000 00:00:1747597371.549862   27163 buffer_comparator.cc:157] Difference at 18: 279.657, expected 244.343
# E0000 00:00:1747597371.549868   27163 buffer_comparator.cc:157] Difference at 23: 282.407, expected 246.965
# E0000 00:00:1747597371.549874   27163 buffer_comparator.cc:157] Difference at 26: 302.46, expected 261.981
# E0000 00:00:1747597371.549880   27163 buffer_comparator.cc:157] Difference at 27: 296.528, expected 257.078
# 2025-05-18 21:42:51.549894: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.555180   27163 buffer_comparator.cc:157] Difference at 1024: 0, expected 237.739
# E0000 00:00:1747597371.555246   27163 buffer_comparator.cc:157] Difference at 1025: 0, expected 245.649
# E0000 00:00:1747597371.555255   27163 buffer_comparator.cc:157] Difference at 1026: 0, expected 247.122
# E0000 00:00:1747597371.555259   27163 buffer_comparator.cc:157] Difference at 1027: 0, expected 247.354
# E0000 00:00:1747597371.555263   27163 buffer_comparator.cc:157] Difference at 1028: 0, expected 242.359
# E0000 00:00:1747597371.555267   27163 buffer_comparator.cc:157] Difference at 1029: 0, expected 243.689
# E0000 00:00:1747597371.555270   27163 buffer_comparator.cc:157] Difference at 1030: 0, expected 249.288
# E0000 00:00:1747597371.555274   27163 buffer_comparator.cc:157] Difference at 1031: 0, expected 230.812
# E0000 00:00:1747597371.555277   27163 buffer_comparator.cc:157] Difference at 1032: 0, expected 234.886
# E0000 00:00:1747597371.555281   27163 buffer_comparator.cc:157] Difference at 1033: 0, expected 236.903
# 2025-05-18 21:42:51.555292: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.561675   27163 buffer_comparator.cc:157] Difference at 1040: 0, expected 250.885
# E0000 00:00:1747597371.561772   27163 buffer_comparator.cc:157] Difference at 1041: 0, expected 242.891
# E0000 00:00:1747597371.561786   27163 buffer_comparator.cc:157] Difference at 1042: 0, expected 234.66
# E0000 00:00:1747597371.561792   27163 buffer_comparator.cc:157] Difference at 1043: 0, expected 245.705
# E0000 00:00:1747597371.561798   27163 buffer_comparator.cc:157] Difference at 1044: 0, expected 240.405
# E0000 00:00:1747597371.561803   27163 buffer_comparator.cc:157] Difference at 1045: 0, expected 240.338
# E0000 00:00:1747597371.561809   27163 buffer_comparator.cc:157] Difference at 1046: 0, expected 252.252
# E0000 00:00:1747597371.561819   27163 buffer_comparator.cc:157] Difference at 1047: 0, expected 239.308
# E0000 00:00:1747597371.561826   27163 buffer_comparator.cc:157] Difference at 1048: 0, expected 244.229
# E0000 00:00:1747597371.561832   27163 buffer_comparator.cc:157] Difference at 1049: 0, expected 237.234
# 2025-05-18 21:42:51.561847: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.569370   27163 buffer_comparator.cc:157] Difference at 1056: 0, expected 237.185
# E0000 00:00:1747597371.569469   27163 buffer_comparator.cc:157] Difference at 1057: 0, expected 241.68
# E0000 00:00:1747597371.569483   27163 buffer_comparator.cc:157] Difference at 1058: 0, expected 245.792
# E0000 00:00:1747597371.569490   27163 buffer_comparator.cc:157] Difference at 1059: 0, expected 242.505
# E0000 00:00:1747597371.569497   27163 buffer_comparator.cc:157] Difference at 1060: 0, expected 248.023
# E0000 00:00:1747597371.569503   27163 buffer_comparator.cc:157] Difference at 1061: 0, expected 256.815
# E0000 00:00:1747597371.569510   27163 buffer_comparator.cc:157] Difference at 1062: 0, expected 243.999
# E0000 00:00:1747597371.569516   27163 buffer_comparator.cc:157] Difference at 1063: 0, expected 233.91
# E0000 00:00:1747597371.569522   27163 buffer_comparator.cc:157] Difference at 1064: 0, expected 246.308
# E0000 00:00:1747597371.569528   27163 buffer_comparator.cc:157] Difference at 1065: 0, expected 242.466
# 2025-05-18 21:42:51.569544: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.574116   27163 buffer_comparator.cc:157] Difference at 2048: 0, expected 352.221
# E0000 00:00:1747597371.574196   27163 buffer_comparator.cc:157] Difference at 2049: 0, expected 357.403
# E0000 00:00:1747597371.574209   27163 buffer_comparator.cc:157] Difference at 2050: 0, expected 354.138
# E0000 00:00:1747597371.574217   27163 buffer_comparator.cc:157] Difference at 2051: 0, expected 358.733
# E0000 00:00:1747597371.574223   27163 buffer_comparator.cc:157] Difference at 2052: 0, expected 352.416
# E0000 00:00:1747597371.574229   27163 buffer_comparator.cc:157] Difference at 2053: 0, expected 352.369
# E0000 00:00:1747597371.574235   27163 buffer_comparator.cc:157] Difference at 2054: 0, expected 363.764
# E0000 00:00:1747597371.574241   27163 buffer_comparator.cc:157] Difference at 2055: 0, expected 338.576
# E0000 00:00:1747597371.574248   27163 buffer_comparator.cc:157] Difference at 2056: 0, expected 342.664
# E0000 00:00:1747597371.574254   27163 buffer_comparator.cc:157] Difference at 2057: 0, expected 345.361
# 2025-05-18 21:42:51.574267: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.578338   27163 buffer_comparator.cc:157] Difference at 3: 289.623, expected 259.283
# E0000 00:00:1747597371.578407   27163 buffer_comparator.cc:157] Difference at 27: 286.065, expected 257.078
# E0000 00:00:1747597371.578421   27163 buffer_comparator.cc:157] Difference at 40: 287.554, expected 255.205
# E0000 00:00:1747597371.578429   27163 buffer_comparator.cc:157] Difference at 42: 280.997, expected 248.623
# E0000 00:00:1747597371.578436   27163 buffer_comparator.cc:157] Difference at 49: 304.787, expected 258.681
# E0000 00:00:1747597371.578443   27163 buffer_comparator.cc:157] Difference at 61: 285.495, expected 255.235
# E0000 00:00:1747597371.578448   27163 buffer_comparator.cc:157] Difference at 67: 267.628, expected 232.294
# E0000 00:00:1747597371.578452   27163 buffer_comparator.cc:157] Difference at 106: 251.898, expected 222.773
# E0000 00:00:1747597371.578456   27163 buffer_comparator.cc:157] Difference at 113: 254.068, expected 226.108
# E0000 00:00:1747597371.578460   27163 buffer_comparator.cc:157] Difference at 131: 157.504, expected 130.874
# 2025-05-18 21:42:51.578469: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.582586   27163 buffer_comparator.cc:157] Difference at 1: 326.975, expected 256.133
# E0000 00:00:1747597371.582640   27163 buffer_comparator.cc:157] Difference at 2: 297.578, expected 258.13
# E0000 00:00:1747597371.582649   27163 buffer_comparator.cc:157] Difference at 3: 309.091, expected 259.283
# E0000 00:00:1747597371.582652   27163 buffer_comparator.cc:157] Difference at 5: 297.859, expected 254.784
# E0000 00:00:1747597371.582657   27163 buffer_comparator.cc:157] Difference at 6: 322.817, expected 262.422
# E0000 00:00:1747597371.582661   27163 buffer_comparator.cc:157] Difference at 8: 279.5, expected 246.547
# E0000 00:00:1747597371.582664   27163 buffer_comparator.cc:157] Difference at 11: 213.098, expected 246.933
# E0000 00:00:1747597371.582668   27163 buffer_comparator.cc:157] Difference at 12: 292.475, expected 256.602
# E0000 00:00:1747597371.582672   27163 buffer_comparator.cc:157] Difference at 14: 296.15, expected 259.382
# E0000 00:00:1747597371.582675   27163 buffer_comparator.cc:157] Difference at 16: 342.083, expected 264.876
# 2025-05-18 21:42:51.582684: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.586424   27163 buffer_comparator.cc:157] Difference at 32: 419.349, expected 252.215
# E0000 00:00:1747597371.586477   27163 buffer_comparator.cc:157] Difference at 33: 407.885, expected 250.388
# E0000 00:00:1747597371.586486   27163 buffer_comparator.cc:157] Difference at 34: 409.923, expected 260.173
# E0000 00:00:1747597371.586490   27163 buffer_comparator.cc:157] Difference at 35: 416.571, expected 253.656
# E0000 00:00:1747597371.586495   27163 buffer_comparator.cc:157] Difference at 36: 386.894, expected 252.701
# E0000 00:00:1747597371.586499   27163 buffer_comparator.cc:157] Difference at 37: 436.727, expected 269.757
# E0000 00:00:1747597371.586503   27163 buffer_comparator.cc:157] Difference at 38: 423.666, expected 253.712
# E0000 00:00:1747597371.586506   27163 buffer_comparator.cc:157] Difference at 39: 412.322, expected 245.159
# E0000 00:00:1747597371.586510   27163 buffer_comparator.cc:157] Difference at 40: 430.911, expected 255.205
# E0000 00:00:1747597371.586513   27163 buffer_comparator.cc:157] Difference at 41: 410.439, expected 252.267
# 2025-05-18 21:42:51.586522: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.590868   27163 buffer_comparator.cc:157] Difference at 32: 419.349, expected 252.215
# E0000 00:00:1747597371.590928   27163 buffer_comparator.cc:157] Difference at 33: 407.885, expected 250.388
# E0000 00:00:1747597371.590937   27163 buffer_comparator.cc:157] Difference at 34: 409.923, expected 260.173
# E0000 00:00:1747597371.590941   27163 buffer_comparator.cc:157] Difference at 35: 416.571, expected 253.656
# E0000 00:00:1747597371.590945   27163 buffer_comparator.cc:157] Difference at 36: 386.894, expected 252.701
# E0000 00:00:1747597371.590948   27163 buffer_comparator.cc:157] Difference at 37: 436.727, expected 269.757
# E0000 00:00:1747597371.590952   27163 buffer_comparator.cc:157] Difference at 38: 423.666, expected 253.712
# E0000 00:00:1747597371.590955   27163 buffer_comparator.cc:157] Difference at 39: 412.322, expected 245.159
# E0000 00:00:1747597371.590959   27163 buffer_comparator.cc:157] Difference at 40: 430.911, expected 255.205
# E0000 00:00:1747597371.590963   27163 buffer_comparator.cc:157] Difference at 41: 410.439, expected 252.267
# 2025-05-18 21:42:51.590972: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.595216   27163 buffer_comparator.cc:157] Difference at 4096: 4.25582, expected 295.966
# E0000 00:00:1747597371.595277   27163 buffer_comparator.cc:157] Difference at 4097: 3.83629, expected 297.85
# E0000 00:00:1747597371.595287   27163 buffer_comparator.cc:157] Difference at 4098: 6.51513, expected 300.911
# E0000 00:00:1747597371.595291   27163 buffer_comparator.cc:157] Difference at 4099: 4.85554, expected 301.47
# E0000 00:00:1747597371.595295   27163 buffer_comparator.cc:157] Difference at 4100: 5.99832, expected 296.586
# E0000 00:00:1747597371.595298   27163 buffer_comparator.cc:157] Difference at 4101: 6.73417, expected 301.246
# E0000 00:00:1747597371.595302   27163 buffer_comparator.cc:157] Difference at 4102: 7.01154, expected 305.284
# E0000 00:00:1747597371.595306   27163 buffer_comparator.cc:157] Difference at 4103: 7.4551, expected 282.733
# E0000 00:00:1747597371.595309   27163 buffer_comparator.cc:157] Difference at 4104: 4.64991, expected 284.502
# E0000 00:00:1747597371.595312   27163 buffer_comparator.cc:157] Difference at 4105: 2.74421, expected 289.553
# 2025-05-18 21:42:51.595322: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.599229   27163 buffer_comparator.cc:157] Difference at 4096: 4.25582, expected 295.966
# E0000 00:00:1747597371.599291   27163 buffer_comparator.cc:157] Difference at 4097: 3.83629, expected 297.85
# E0000 00:00:1747597371.599300   27163 buffer_comparator.cc:157] Difference at 4098: 6.51513, expected 300.911
# E0000 00:00:1747597371.599304   27163 buffer_comparator.cc:157] Difference at 4099: 4.85554, expected 301.47
# E0000 00:00:1747597371.599309   27163 buffer_comparator.cc:157] Difference at 4100: 5.99832, expected 296.586
# E0000 00:00:1747597371.599312   27163 buffer_comparator.cc:157] Difference at 4101: 6.73417, expected 301.246
# E0000 00:00:1747597371.599316   27163 buffer_comparator.cc:157] Difference at 4102: 7.01154, expected 305.284
# E0000 00:00:1747597371.599319   27163 buffer_comparator.cc:157] Difference at 4103: 7.4551, expected 282.733
# E0000 00:00:1747597371.599323   27163 buffer_comparator.cc:157] Difference at 4104: 4.64991, expected 284.502
# E0000 00:00:1747597371.599326   27163 buffer_comparator.cc:157] Difference at 4105: 2.74421, expected 289.553
# 2025-05-18 21:42:51.599335: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.610438   27163 buffer_comparator.cc:157] Difference at 1216: 110.999, expected 124.526
# E0000 00:00:1747597371.610498   27163 buffer_comparator.cc:157] Difference at 1217: 112.213, expected 129.215
# E0000 00:00:1747597371.610523   27163 buffer_comparator.cc:157] Difference at 5451: 125.092, expected 139.733
# 2025-05-18 21:42:51.610543: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.615517   27163 buffer_comparator.cc:157] Difference at 3: 289.623, expected 259.283
# E0000 00:00:1747597371.615587   27163 buffer_comparator.cc:157] Difference at 27: 286.065, expected 257.078
# E0000 00:00:1747597371.615597   27163 buffer_comparator.cc:157] Difference at 40: 287.554, expected 255.205
# E0000 00:00:1747597371.615601   27163 buffer_comparator.cc:157] Difference at 42: 280.997, expected 248.623
# E0000 00:00:1747597371.615605   27163 buffer_comparator.cc:157] Difference at 49: 304.787, expected 258.681
# E0000 00:00:1747597371.615610   27163 buffer_comparator.cc:157] Difference at 61: 285.495, expected 255.235
# E0000 00:00:1747597371.615614   27163 buffer_comparator.cc:157] Difference at 67: 267.628, expected 232.294
# E0000 00:00:1747597371.615618   27163 buffer_comparator.cc:157] Difference at 106: 251.898, expected 222.773
# E0000 00:00:1747597371.615622   27163 buffer_comparator.cc:157] Difference at 113: 254.068, expected 226.108
# E0000 00:00:1747597371.615626   27163 buffer_comparator.cc:157] Difference at 131: 157.504, expected 130.874
# 2025-05-18 21:42:51.615636: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.621114   27163 buffer_comparator.cc:157] Difference at 16: 292.867, expected 74.4591
# E0000 00:00:1747597371.621183   27163 buffer_comparator.cc:157] Difference at 17: 258.6, expected 66.3701
# E0000 00:00:1747597371.621193   27163 buffer_comparator.cc:157] Difference at 18: 245.29, expected 68.8619
# E0000 00:00:1747597371.621198   27163 buffer_comparator.cc:157] Difference at 19: 262.474, expected 71.1305
# E0000 00:00:1747597371.621202   27163 buffer_comparator.cc:157] Difference at 20: 259.544, expected 67.7619
# E0000 00:00:1747597371.621206   27163 buffer_comparator.cc:157] Difference at 21: 243.815, expected 67.3062
# E0000 00:00:1747597371.621209   27163 buffer_comparator.cc:157] Difference at 22: 264.012, expected 68.2975
# E0000 00:00:1747597371.621213   27163 buffer_comparator.cc:157] Difference at 23: 256.767, expected 59.5664
# E0000 00:00:1747597371.621217   27163 buffer_comparator.cc:157] Difference at 24: 266.422, expected 69.2017
# E0000 00:00:1747597371.621220   27163 buffer_comparator.cc:157] Difference at 25: 269.175, expected 68.5863
# 2025-05-18 21:42:51.621230: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.624432   27163 buffer_comparator.cc:157] Difference at 16: 292.867, expected 74.4591
# E0000 00:00:1747597371.624483   27163 buffer_comparator.cc:157] Difference at 17: 258.6, expected 66.3701
# E0000 00:00:1747597371.624492   27163 buffer_comparator.cc:157] Difference at 18: 245.29, expected 68.8619
# E0000 00:00:1747597371.624496   27163 buffer_comparator.cc:157] Difference at 19: 262.474, expected 71.1305
# E0000 00:00:1747597371.624501   27163 buffer_comparator.cc:157] Difference at 20: 259.544, expected 67.7619
# E0000 00:00:1747597371.624504   27163 buffer_comparator.cc:157] Difference at 21: 243.815, expected 67.3062
# E0000 00:00:1747597371.624508   27163 buffer_comparator.cc:157] Difference at 22: 264.012, expected 68.2975
# E0000 00:00:1747597371.624511   27163 buffer_comparator.cc:157] Difference at 23: 256.767, expected 59.5664
# E0000 00:00:1747597371.624515   27163 buffer_comparator.cc:157] Difference at 24: 266.422, expected 69.2017
# E0000 00:00:1747597371.624519   27163 buffer_comparator.cc:157] Difference at 25: 269.175, expected 68.5863
# 2025-05-18 21:42:51.624527: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.628777   27163 buffer_comparator.cc:157] Difference at 4: 74.0131, expected 64.6046
# E0000 00:00:1747597371.628848   27163 buffer_comparator.cc:157] Difference at 25: 76.4552, expected 68.5863
# E0000 00:00:1747597371.628862   27163 buffer_comparator.cc:157] Difference at 43: 57.5264, expected 64.6972
# E0000 00:00:1747597371.628869   27163 buffer_comparator.cc:157] Difference at 60: 71.8947, expected 64.4762
# E0000 00:00:1747597371.628875   27163 buffer_comparator.cc:157] Difference at 68: 72.3583, expected 62.385
# E0000 00:00:1747597371.628882   27163 buffer_comparator.cc:157] Difference at 132: 66.3846, expected 58.9071
# E0000 00:00:1747597371.628889   27163 buffer_comparator.cc:157] Difference at 153: 69.2428, expected 61.4907
# E0000 00:00:1747597371.628896   27163 buffer_comparator.cc:157] Difference at 188: 66.0781, expected 57.3868
# E0000 00:00:1747597371.628903   27163 buffer_comparator.cc:157] Difference at 196: 69.6591, expected 60.5085
# E0000 00:00:1747597371.628910   27163 buffer_comparator.cc:157] Difference at 217: 72.8988, expected 64.6393
# 2025-05-18 21:42:51.628921: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.632859   27163 buffer_comparator.cc:157] Difference at 1024: 75.8389, expected 65.4676
# E0000 00:00:1747597371.632913   27163 buffer_comparator.cc:157] Difference at 1025: 83.3407, expected 62.7145
# E0000 00:00:1747597371.632922   27163 buffer_comparator.cc:157] Difference at 1026: 83.7652, expected 69.3355
# E0000 00:00:1747597371.632926   27163 buffer_comparator.cc:157] Difference at 1027: 88.5472, expected 71.8848
# E0000 00:00:1747597371.632930   27163 buffer_comparator.cc:157] Difference at 1028: 76.5048, expected 60.1548
# E0000 00:00:1747597371.632933   27163 buffer_comparator.cc:157] Difference at 1029: 80.0078, expected 66.3009
# E0000 00:00:1747597371.632937   27163 buffer_comparator.cc:157] Difference at 1030: 83.1912, expected 69.2194
# E0000 00:00:1747597371.632941   27163 buffer_comparator.cc:157] Difference at 1031: 76.5325, expected 60.5966
# E0000 00:00:1747597371.632944   27163 buffer_comparator.cc:157] Difference at 1032: 82.2318, expected 64.6332
# E0000 00:00:1747597371.632948   27163 buffer_comparator.cc:157] Difference at 1033: 71.7987, expected 62.779
# 2025-05-18 21:42:51.632956: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.637382   27163 buffer_comparator.cc:157] Difference at 1040: 89.3169, expected 71.7533
# E0000 00:00:1747597371.637449   27163 buffer_comparator.cc:157] Difference at 1041: 77.1401, expected 64.2298
# E0000 00:00:1747597371.637459   27163 buffer_comparator.cc:157] Difference at 1043: 82.4868, expected 66.5319
# E0000 00:00:1747597371.637463   27163 buffer_comparator.cc:157] Difference at 1044: 76.7517, expected 67.6749
# E0000 00:00:1747597371.637467   27163 buffer_comparator.cc:157] Difference at 1046: 80.2139, expected 68.5063
# E0000 00:00:1747597371.637471   27163 buffer_comparator.cc:157] Difference at 1047: 76.4964, expected 61.9326
# E0000 00:00:1747597371.637475   27163 buffer_comparator.cc:157] Difference at 1048: 80.8519, expected 65.6029
# E0000 00:00:1747597371.637478   27163 buffer_comparator.cc:157] Difference at 1049: 77.8709, expected 64.3103
# E0000 00:00:1747597371.637482   27163 buffer_comparator.cc:157] Difference at 1050: 85.1314, expected 65.974
# E0000 00:00:1747597371.637485   27163 buffer_comparator.cc:157] Difference at 1051: 83.9815, expected 63.2123
# 2025-05-18 21:42:51.637496: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.641174   27163 buffer_comparator.cc:157] Difference at 1068: 62.6563, expected 70.6674
# E0000 00:00:1747597371.641226   27163 buffer_comparator.cc:157] Difference at 1082: 65.0562, expected 58.3163
# E0000 00:00:1747597371.641235   27163 buffer_comparator.cc:157] Difference at 1184: 46.5451, expected 63.2182
# E0000 00:00:1747597371.641239   27163 buffer_comparator.cc:157] Difference at 1185: 46.3304, expected 60.3538
# E0000 00:00:1747597371.641243   27163 buffer_comparator.cc:157] Difference at 1186: 48.0878, expected 66.6234
# E0000 00:00:1747597371.641247   27163 buffer_comparator.cc:157] Difference at 1187: 48.7985, expected 66.5687
# E0000 00:00:1747597371.641251   27163 buffer_comparator.cc:157] Difference at 1188: 44.9372, expected 64.4337
# E0000 00:00:1747597371.641254   27163 buffer_comparator.cc:157] Difference at 1189: 51.4676, expected 71.5062
# E0000 00:00:1747597371.641258   27163 buffer_comparator.cc:157] Difference at 1190: 51.0801, expected 63.6907
# E0000 00:00:1747597371.641261   27163 buffer_comparator.cc:157] Difference at 1191: 46.534, expected 61.5592
# 2025-05-18 21:42:51.641270: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.645645   27163 buffer_comparator.cc:157] Difference at 2048: 103.497, expected 67.7365
# E0000 00:00:1747597371.645722   27163 buffer_comparator.cc:157] Difference at 2049: 113.474, expected 65.8303
# E0000 00:00:1747597371.645734   27163 buffer_comparator.cc:157] Difference at 2050: 113.262, expected 72.3531
# E0000 00:00:1747597371.645738   27163 buffer_comparator.cc:157] Difference at 2051: 121.828, expected 74.5188
# E0000 00:00:1747597371.645743   27163 buffer_comparator.cc:157] Difference at 2052: 103.282, expected 63.5186
# E0000 00:00:1747597371.645746   27163 buffer_comparator.cc:157] Difference at 2053: 110.551, expected 69.9178
# E0000 00:00:1747597371.645750   27163 buffer_comparator.cc:157] Difference at 2054: 111.872, expected 69.8654
# E0000 00:00:1747597371.645753   27163 buffer_comparator.cc:157] Difference at 2055: 104.401, expected 64.2937
# E0000 00:00:1747597371.645757   27163 buffer_comparator.cc:157] Difference at 2056: 108.279, expected 69.536
# E0000 00:00:1747597371.645760   27163 buffer_comparator.cc:157] Difference at 2057: 97.8116, expected 64.4295
# 2025-05-18 21:42:51.645771: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.650137   27163 buffer_comparator.cc:157] Difference at 1: 79.6034, expected 68.4472
# E0000 00:00:1747597371.650227   27163 buffer_comparator.cc:157] Difference at 3: 83.2625, expected 74.7697
# E0000 00:00:1747597371.650244   27163 buffer_comparator.cc:157] Difference at 9: 55.1642, expected 64.9645
# E0000 00:00:1747597371.650252   27163 buffer_comparator.cc:157] Difference at 11: 48.9694, expected 65.9511
# E0000 00:00:1747597371.650259   27163 buffer_comparator.cc:157] Difference at 20: 59.1144, expected 67.7619
# E0000 00:00:1747597371.650266   27163 buffer_comparator.cc:157] Difference at 30: 76.1034, expected 67.045
# E0000 00:00:1747597371.650271   27163 buffer_comparator.cc:157] Difference at 31: 49.3973, expected 61.3991
# E0000 00:00:1747597371.650277   27163 buffer_comparator.cc:157] Difference at 60: 72.8072, expected 64.4762
# E0000 00:00:1747597371.650283   27163 buffer_comparator.cc:157] Difference at 63: 72.0913, expected 64.4686
# E0000 00:00:1747597371.650288   27163 buffer_comparator.cc:157] Difference at 73: 49.6901, expected 62.2625
# 2025-05-18 21:42:51.650300: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.654168   27163 buffer_comparator.cc:157] Difference at 60: 72.8072, expected 64.4762
# E0000 00:00:1747597371.654239   27163 buffer_comparator.cc:157] Difference at 63: 72.0913, expected 64.4686
# E0000 00:00:1747597371.654249   27163 buffer_comparator.cc:157] Difference at 124: 72.7795, expected 64.0992
# E0000 00:00:1747597371.654254   27163 buffer_comparator.cc:157] Difference at 188: 67.071, expected 57.3868
# E0000 00:00:1747597371.654258   27163 buffer_comparator.cc:157] Difference at 191: 65.6185, expected 58.0603
# E0000 00:00:1747597371.654262   27163 buffer_comparator.cc:157] Difference at 240: 71.0153, expected 62.5994
# E0000 00:00:1747597371.654266   27163 buffer_comparator.cc:157] Difference at 242: 69.8007, expected 61.792
# E0000 00:00:1747597371.654269   27163 buffer_comparator.cc:157] Difference at 252: 72.8146, expected 61.0918
# E0000 00:00:1747597371.654273   27163 buffer_comparator.cc:157] Difference at 316: 71.1834, expected 62.1454
# E0000 00:00:1747597371.654277   27163 buffer_comparator.cc:157] Difference at 319: 67.2516, expected 59.2762
# 2025-05-18 21:42:51.654287: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.658229   27163 buffer_comparator.cc:157] Difference at 60: 72.8072, expected 64.4762
# E0000 00:00:1747597371.658351   27163 buffer_comparator.cc:157] Difference at 63: 72.0913, expected 64.4686
# E0000 00:00:1747597371.658363   27163 buffer_comparator.cc:157] Difference at 124: 72.7795, expected 64.0992
# E0000 00:00:1747597371.658369   27163 buffer_comparator.cc:157] Difference at 188: 67.071, expected 57.3868
# E0000 00:00:1747597371.658375   27163 buffer_comparator.cc:157] Difference at 191: 65.6185, expected 58.0603
# E0000 00:00:1747597371.658380   27163 buffer_comparator.cc:157] Difference at 240: 71.0153, expected 62.5994
# E0000 00:00:1747597371.658387   27163 buffer_comparator.cc:157] Difference at 242: 69.8007, expected 61.792
# E0000 00:00:1747597371.658393   27163 buffer_comparator.cc:157] Difference at 252: 72.8146, expected 61.0918
# E0000 00:00:1747597371.658399   27163 buffer_comparator.cc:157] Difference at 316: 71.1834, expected 62.1454
# E0000 00:00:1747597371.658404   27163 buffer_comparator.cc:157] Difference at 319: 67.2516, expected 59.2762
# 2025-05-18 21:42:51.658420: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.662745   27163 buffer_comparator.cc:157] Difference at 4096: 72.6396, expected 63.4237
# E0000 00:00:1747597371.662817   27163 buffer_comparator.cc:157] Difference at 4097: 73.7525, expected 62.2674
# E0000 00:00:1747597371.662826   27163 buffer_comparator.cc:157] Difference at 4098: 77.184, expected 67.7224
# E0000 00:00:1747597371.662830   27163 buffer_comparator.cc:157] Difference at 4099: 81.6045, expected 68.5948
# E0000 00:00:1747597371.662834   27163 buffer_comparator.cc:157] Difference at 4100: 73.3916, expected 56.4092
# E0000 00:00:1747597371.662838   27163 buffer_comparator.cc:157] Difference at 4101: 75.407, expected 65.3777
# E0000 00:00:1747597371.662842   27163 buffer_comparator.cc:157] Difference at 4103: 73.9821, expected 58.0208
# E0000 00:00:1747597371.662846   27163 buffer_comparator.cc:157] Difference at 4104: 74.5689, expected 63.9328
# E0000 00:00:1747597371.662849   27163 buffer_comparator.cc:157] Difference at 4106: 72.4328, expected 62.842
# E0000 00:00:1747597371.662853   27163 buffer_comparator.cc:157] Difference at 4107: 69.3164, expected 59.4994
# 2025-05-18 21:42:51.662864: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.667566   27163 buffer_comparator.cc:157] Difference at 4096: 72.6396, expected 63.4237
# E0000 00:00:1747597371.667661   27163 buffer_comparator.cc:157] Difference at 4097: 73.7525, expected 62.2674
# E0000 00:00:1747597371.667670   27163 buffer_comparator.cc:157] Difference at 4098: 77.184, expected 67.7224
# E0000 00:00:1747597371.667674   27163 buffer_comparator.cc:157] Difference at 4099: 81.6045, expected 68.5948
# E0000 00:00:1747597371.667678   27163 buffer_comparator.cc:157] Difference at 4100: 73.3916, expected 56.4092
# E0000 00:00:1747597371.667682   27163 buffer_comparator.cc:157] Difference at 4101: 75.407, expected 65.3777
# E0000 00:00:1747597371.667686   27163 buffer_comparator.cc:157] Difference at 4103: 73.9821, expected 58.0208
# E0000 00:00:1747597371.667689   27163 buffer_comparator.cc:157] Difference at 4104: 74.5689, expected 63.9328
# E0000 00:00:1747597371.667693   27163 buffer_comparator.cc:157] Difference at 4106: 72.4328, expected 62.842
# E0000 00:00:1747597371.667697   27163 buffer_comparator.cc:157] Difference at 4107: 69.3164, expected 59.4994
# 2025-05-18 21:42:51.667707: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.671427   27163 buffer_comparator.cc:157] Difference at 4096: 72.6396, expected 63.4237
# E0000 00:00:1747597371.671483   27163 buffer_comparator.cc:157] Difference at 4097: 73.7525, expected 62.2674
# E0000 00:00:1747597371.671492   27163 buffer_comparator.cc:157] Difference at 4098: 77.184, expected 67.7224
# E0000 00:00:1747597371.671497   27163 buffer_comparator.cc:157] Difference at 4099: 81.6045, expected 68.5948
# E0000 00:00:1747597371.671501   27163 buffer_comparator.cc:157] Difference at 4100: 73.3916, expected 56.4092
# E0000 00:00:1747597371.671504   27163 buffer_comparator.cc:157] Difference at 4101: 75.407, expected 65.3777
# E0000 00:00:1747597371.671508   27163 buffer_comparator.cc:157] Difference at 4103: 73.9821, expected 58.0208
# E0000 00:00:1747597371.671511   27163 buffer_comparator.cc:157] Difference at 4104: 74.5689, expected 63.9328
# E0000 00:00:1747597371.671515   27163 buffer_comparator.cc:157] Difference at 4106: 72.4328, expected 62.842
# E0000 00:00:1747597371.671518   27163 buffer_comparator.cc:157] Difference at 4107: 69.3164, expected 59.4994
# 2025-05-18 21:42:51.671527: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.675998   27163 buffer_comparator.cc:157] Difference at 8192: 34.4089, expected 65.7324
# E0000 00:00:1747597371.676055   27163 buffer_comparator.cc:157] Difference at 8193: 42.2162, expected 64.2455
# E0000 00:00:1747597371.676064   27163 buffer_comparator.cc:157] Difference at 8194: 39.1556, expected 69.0756
# E0000 00:00:1747597371.676068   27163 buffer_comparator.cc:157] Difference at 8195: 40.9391, expected 70.7496
# E0000 00:00:1747597371.676071   27163 buffer_comparator.cc:157] Difference at 8196: 33.5559, expected 60.1083
# E0000 00:00:1747597371.676075   27163 buffer_comparator.cc:157] Difference at 8197: 40.5123, expected 67.329
# E0000 00:00:1747597371.676079   27163 buffer_comparator.cc:157] Difference at 8198: 42.625, expected 68.8059
# E0000 00:00:1747597371.676082   27163 buffer_comparator.cc:157] Difference at 8199: 36.5026, expected 62.3181
# E0000 00:00:1747597371.676086   27163 buffer_comparator.cc:157] Difference at 8200: 37.0392, expected 66.8826
# E0000 00:00:1747597371.676089   27163 buffer_comparator.cc:157] Difference at 8201: 32.404, expected 62.5059
# 2025-05-18 21:42:51.676099: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.679550   27163 buffer_comparator.cc:157] Difference at 8192: 34.4089, expected 65.7324
# E0000 00:00:1747597371.679604   27163 buffer_comparator.cc:157] Difference at 8193: 42.2162, expected 64.2455
# E0000 00:00:1747597371.679614   27163 buffer_comparator.cc:157] Difference at 8194: 39.1556, expected 69.0756
# E0000 00:00:1747597371.679618   27163 buffer_comparator.cc:157] Difference at 8195: 40.9391, expected 70.7496
# E0000 00:00:1747597371.679622   27163 buffer_comparator.cc:157] Difference at 8196: 33.5559, expected 60.1083
# E0000 00:00:1747597371.679626   27163 buffer_comparator.cc:157] Difference at 8197: 40.5123, expected 67.329
# E0000 00:00:1747597371.679629   27163 buffer_comparator.cc:157] Difference at 8198: 42.625, expected 68.8059
# E0000 00:00:1747597371.679633   27163 buffer_comparator.cc:157] Difference at 8199: 36.5026, expected 62.3181
# E0000 00:00:1747597371.679636   27163 buffer_comparator.cc:157] Difference at 8200: 37.0392, expected 66.8826
# E0000 00:00:1747597371.679640   27163 buffer_comparator.cc:157] Difference at 8201: 32.404, expected 62.5059
# 2025-05-18 21:42:51.679649: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.683382   27163 buffer_comparator.cc:157] Difference at 0: 62.5199, expected 69.6635
# E0000 00:00:1747597371.683519   27163 buffer_comparator.cc:157] Difference at 10: 55.3989, expected 65.043
# E0000 00:00:1747597371.683544   27163 buffer_comparator.cc:157] Difference at 11: 57.2411, expected 65.9511
# E0000 00:00:1747597371.683554   27163 buffer_comparator.cc:157] Difference at 31: 52.9188, expected 61.3991
# E0000 00:00:1747597371.683563   27163 buffer_comparator.cc:157] Difference at 36: 59.1212, expected 66.5532
# E0000 00:00:1747597371.683571   27163 buffer_comparator.cc:157] Difference at 45: 59.9638, expected 67.3664
# E0000 00:00:1747597371.683580   27163 buffer_comparator.cc:157] Difference at 64: 59.6322, expected 66.9789
# E0000 00:00:1747597371.683588   27163 buffer_comparator.cc:157] Difference at 68: 54.2269, expected 62.385
# E0000 00:00:1747597371.683595   27163 buffer_comparator.cc:157] Difference at 74: 49.5086, expected 64.7137
# E0000 00:00:1747597371.683603   27163 buffer_comparator.cc:157] Difference at 75: 51.86, expected 61.9036
# 2025-05-18 21:42:51.683619: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1747597371.687762   27163 buffer_comparator.cc:157] Difference at 8192: 32.6718, expected 65.7324
# E0000 00:00:1747597371.687818   27163 buffer_comparator.cc:157] Difference at 8193: 40.8719, expected 64.2455
# E0000 00:00:1747597371.687827   27163 buffer_comparator.cc:157] Difference at 8194: 37.1973, expected 69.0756
# E0000 00:00:1747597371.687831   27163 buffer_comparator.cc:157] Difference at 8195: 38.6364, expected 70.7496
# E0000 00:00:1747597371.687835   27163 buffer_comparator.cc:157] Difference at 8196: 31.5812, expected 60.1083
# E0000 00:00:1747597371.687839   27163 buffer_comparator.cc:157] Difference at 8197: 37.2323, expected 67.329
# E0000 00:00:1747597371.687842   27163 buffer_comparator.cc:157] Difference at 8198: 40.3521, expected 68.8059
# E0000 00:00:1747597371.687846   27163 buffer_comparator.cc:157] Difference at 8199: 33.7122, expected 62.3181
# E0000 00:00:1747597371.687850   27163 buffer_comparator.cc:157] Difference at 8200: 34.9375, expected 66.8826
# E0000 00:00:1747597371.687853   27163 buffer_comparator.cc:157] Difference at 8201: 31.7167, expected 62.5059
# 2025-05-18 21:42:51.687862: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# W0000 00:00:1747597371.925965   27163 gpu_backend_lib.cc:617] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2025-05-18 21:42:51.929668: W tensorflow/core/framework/op_kernel.cc:1841] OP_REQUIRES failed at xla_ops.cc:577 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2025-05-18 21:42:51.929779: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INTERNAL: libdevice not found at ./libdevice.10.bc
# 	 [[{{node StatefulPartitionedCall}}]]
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[6], line 10
#       1 model = keras.Sequential([
#       2     layers.Dense(128, activation='relu', input_shape=input_shape),
#       3     layers.Dense(64, activation='relu'),
#       4     layers.Dense(1)
#       5 ])
#       6 model.compile(
#       7     optimizer='adam',
#       8     loss='mae',
#       9 )
# ---> 10 history = model.fit(
#      11     X_train, y_train,
#      12     validation_data=(X_valid, y_valid),
#      13     batch_size=512,
#      14     epochs=50,
#      15 )
#      16 history_df = pd.DataFrame(history.history)
#      17 history_df.loc[:, ['loss', 'val_loss']].plot()
#
# File ~/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniforge3/envs/EnvDL/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InternalError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/asyncio/events.py", line 88, in _run
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3098, in run_cell
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3153, in _run_cell
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3365, in run_cell_async
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3610, in run_ast_nodes
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3670, in run_code
#
#   File "/tmp/ipykernel_879/1271964287.py", line 10, in <module>
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 371, in fit
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 219, in function
#
#   File "/home/caujoulat/miniforge3/envs/EnvDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 132, in multi_step_on_iterator
#
# libdevice not found at ./libdevice.10.bc
# 	 [[{{node StatefulPartitionedCall}}]] [Op:__inference_multi_step_on_iterator_1828]

# %% [markdown]
# ## 2) Add capacity

# %%
# View the solution (Run this cell to receive credit!)
q_2.check()
# Out:
# Correct:
#
# Now the validation loss begins to rise very early, while the training loss continues to decrease. This indicates that the network has begun to overfit. At this point, we would need to try something to prevent it, either by reducing the number of units or through a method like early stopping. (We'll see another in the next lesson!)

# %% [markdown]
# ## 3) Define Early Stopping Callback

# %%
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import EarlyStopping

# YOUR CODE HERE: define an early stopping callback
early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=5, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# Check your answer
q_3.check()
# Out:
# Incorrect: The `min_delta` argument should be 0.001.
